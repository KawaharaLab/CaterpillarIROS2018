# %%
import numpy as np
import pandas as pd
import os
import re
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
def mean_std(path: str, file="reward", metric="reward"):
    distances = {}
    for i, trial in enumerate(filter(lambda x: re.match(r'^trial[0-9]+$', x), os.listdir(path))):
        data_path = os.path.join(path, trial, "train_log", "{}.txt".format(file))
        df = pd.read_csv(data_path)
        distances[trial] = df[metric]
    all_distance_df = pd.DataFrame(distances)
    
    return all_distance_df.mean(1), all_distance_df.std(1)

# %%
y, err = mean_std("results/fric_linear_tension/run1", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='linear model')
plt.fill_between(x, y - err, y + err, alpha=0.2)

# y, err = train_mean_std("results/linear/run0")
# x = np.arange(len(y))
# plt.plot(x, y, linestyle='--', label='linear')
# plt.fill_between(x, y - err, y + err, alpha=0.3)

# plt.ylim([0.6, 2.5])

plt.legend(loc='lower right')

plt.xlabel("Episodes")
plt.ylabel("Locomotion distance per 10000 steps")

plt.savefig("graphs/LearningCurve_LinearFrictionTention.png")

# %%
y, err = mean_std("results/fric_linear_tension/run1", 'sigma', 'average sigma')
x = np.arange(len(y))
plt.plot(x, y, label='linear model')
plt.fill_between(x, y - err, y + err, alpha=0.2)

# y, err = train_mean_std("results/linear/run0")
# x = np.arange(len(y))
# plt.plot(x, y, linestyle='--', label='linear')
# plt.fill_between(x, y - err, y + err, alpha=0.3)

# plt.ylim([0.6, 2.5])

plt.legend(loc='upper right')

plt.xlabel("Episodes")
plt.ylabel("Average sigma")

plt.savefig("graphs/SigmaCurve_LinearFrictionTention.png")

# %%
y, err = mean_std("results/fric_linear_tension_5000/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='linear model')
plt.fill_between(x, y - err, y + err, alpha=0.2)

plt.legend(loc='lower right')

plt.xlabel("Episodes")
plt.ylabel("Locomotion distance per 10000 steps")

plt.savefig("graphs/LearningCurve_LinearFrictionTention5000.png")

# %%
y, err = mean_std("results/fric_linear_tension_5000/run0", 'sigma', 'average sigma')
x = np.arange(len(y))
plt.plot(x, y, label='linear model')
plt.fill_between(x, y - err, y + err, alpha=0.2)

plt.legend(loc='upper right')

plt.xlabel("Episodes")
plt.ylabel("Average sigma")

plt.savefig("graphs/SigmaCurve_LinearFrictionTention5000.png")

# %%
y, err = mean_std("results/threshold_tanh/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='linear model')
plt.fill_between(x, y - err, y + err, alpha=0.2)

plt.legend(loc='lower right')

plt.xlabel("Episodes")
plt.ylabel("Locomotion distance per 10000 steps")

plt.savefig("graphs/LearningCurve_GrippingThreshold_tanh.png")

# %%
y, err = mean_std("results/threshold_tanh/run0", 'sigma', 'average sigma')
x = np.arange(len(y))
plt.plot(x, y, label='linear model')
plt.fill_between(x, y - err, y + err, alpha=0.2)

plt.legend(loc='upper right')

plt.xlabel("Episodes")
plt.ylabel("Average sigma")

plt.savefig("graphs/SigmaCurve_GrippingThreshold_tanh.png")

# %%
y, err = mean_std("results/threshold/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='linear model')
plt.fill_between(x, y - err, y + err, alpha=0.2)

plt.legend(loc='lower right')

plt.xlabel("Episodes")
plt.ylabel("Locomotion distance per 10000 steps")

plt.savefig("graphs/LearningCurve_GrippingThreshold.png")

# %%
y, err = mean_std("results/threshold/run0", 'sigma', 'average sigma')
x = np.arange(len(y))
plt.plot(x, y, label='linear model')
plt.fill_between(x, y - err, y + err, alpha=0.2)

plt.legend(loc='upper right')

plt.xlabel("Episodes")
plt.ylabel("Average sigma")

plt.savefig("graphs/SigmaCurve_GrippingThreshold.png")

# %%
y, err = mean_std("results/fric_linear/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='linear model')
plt.fill_between(x, y - err, y + err, alpha=0.2)

plt.legend(loc='lower right')

plt.xlabel("Episodes")
plt.ylabel("Locomotion distance per 10000 steps")

plt.savefig("graphs/LearningCurve_OnlyFrictions.png")

# %%
y, err = mean_std("results/fric_linear/run0", 'sigma', 'average sigma')
x = np.arange(len(y))
plt.plot(x, y, label='linear model')
plt.fill_between(x, y - err, y + err, alpha=0.2)

plt.legend(loc='upper right')

plt.xlabel("Episodes")
plt.ylabel("Average sigma")

plt.savefig("graphs/SigmaCurve_OnlyFriction.png")

# %%
y, err = mean_std("results/fric_nn_tension/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='linear model')
plt.fill_between(x, y - err, y + err, alpha=0.2)

plt.legend(loc='lower right')

plt.xlabel("Episodes")
plt.ylabel("Locomotion distance per 10000 steps")

plt.savefig("graphs/LearningCurve_NNTension.png")

# %%
y, err = mean_std("results/fric_nn_tension/run0", 'sigma', 'average sigma')
x = np.arange(len(y))
plt.plot(x, y, label='linear model')
plt.fill_between(x, y - err, y + err, alpha=0.2)

plt.legend(loc='upper right')

plt.xlabel("Episodes")
plt.ylabel("Average sigma")

plt.savefig("graphs/SigmaCurve_NNTension.png")

# %%
y, err = mean_std("results/muscle/normal/k3/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='linear model')
plt.fill_between(x, y - err, y + err, alpha=0.2)

plt.legend(loc='lower right')

plt.xlabel("Episodes")
plt.ylabel("Locomotion distance per 5000 steps")

plt.savefig("graphs/LearningCurve_Normal_k3.png")

# %%
y, err = mean_std("results/muscle/normal/k3/run0", 'sigma', 'average sigma')
x = np.arange(len(y))
plt.plot(x, y, label='linear model')
plt.fill_between(x, y - err, y + err, alpha=0.2)

plt.legend(loc='upper right')

plt.xlabel("Episodes")
plt.ylabel("Average sigma")

plt.savefig("graphs/SigmaCurve_Normal_k3.png")

# %%
y, err = mean_std("results/muscle/normal/k9/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='linear model')
plt.fill_between(x, y - err, y + err, alpha=0.2)

plt.legend(loc='lower right')

plt.xlabel("Episodes")
plt.ylabel("Locomotion distance per 5000 steps")

plt.savefig("graphs/LearningCurve_Normal_k9.png")

# %%
y, err = mean_std("results/muscle/normal/k15/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='linear model')
plt.fill_between(x, y - err, y + err, alpha=0.2)

plt.legend(loc='lower right')

plt.xlabel("Episodes")
plt.ylabel("Locomotion distance per 5000 steps")

plt.savefig("graphs/LearningCurve_Normal_k15.png")

# %%
y, err = mean_std("results/muscle/normal/k40/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='linear model')
plt.fill_between(x, y - err, y + err, alpha=0.2)

plt.legend(loc='lower right')

plt.xlabel("Episodes")
plt.ylabel("Locomotion distance per 5000 steps")

plt.savefig("graphs/LearningCurve_Normal_k40.png")

# %%
y, err = mean_std("results/muscle/normal/k100/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='linear model')
plt.fill_between(x, y - err, y + err, alpha=0.2)

plt.legend(loc='lower right')

plt.xlabel("Episodes")
plt.ylabel("Locomotion distance per 5000 steps")

plt.savefig("graphs/LearningCurve_Normal_k100.png")

# %%
# average over 20 trials
# k3
y, err = mean_std("results/muscle/normal/k3/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='k3')
plt.fill_between(x, y - err, y + err, alpha=0.2)

# k9
y, err = mean_std("results/muscle/normal/k9/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='k9')
plt.fill_between(x, y - err, y + err, alpha=0.2)

# k15
y, err = mean_std("results/muscle/normal/k15/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='k15')
plt.fill_between(x, y - err, y + err, alpha=0.2)

# k40
y, err = mean_std("results/muscle/normal/k40/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='k40')
plt.fill_between(x, y - err, y + err, alpha=0.2)

# k100
y, err = mean_std("results/muscle/normal/k100/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='k100')
plt.fill_between(x, y - err, y + err, alpha=0.2)

plt.legend(loc='lower right')

plt.ylim([0, 600])
plt.ylim([-1, 9])

plt.xlabel("Episodes")
plt.ylabel("Locomotion distance per 5000 steps")

plt.savefig("graphs/LearningCurve_Normal_k.png")

# %%
# k3
y, err = mean_std("results/muscle/adaptive_threshold/k3/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='k3')
plt.fill_between(x, y - err, y + err, alpha=0.2)

# k9
y, err = mean_std("results/muscle/adaptive_threshold/k9/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='k9')
plt.fill_between(x, y - err, y + err, alpha=0.2)

# k15
y, err = mean_std("results/muscle/adaptive_threshold/k15/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='k15')
plt.fill_between(x, y - err, y + err, alpha=0.2)

# k40
y, err = mean_std("results/muscle/adaptive_threshold/k40/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='k40')
plt.fill_between(x, y - err, y + err, alpha=0.2)

# k100
y, err = mean_std("results/muscle/adaptive_threshold/k100/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, label='k100')
plt.fill_between(x, y - err, y + err, alpha=0.2)

plt.legend(loc='lower right')

plt.ylim([-1, 10])

plt.xlabel("Episodes")
plt.ylabel("Locomotion distance per 5000 steps")

plt.savefig("graphs/LearningCurve_AdaptiveGrippingThreshold_k.png")

# %%
# # # 5 somites 5 legs
y, err = mean_std("results/long/5s5l/run0", "distance", "distance")
# y, err = mean_std("results/muscle/normal/k9/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, '-', label='s:5, l:5')
plt.fill_between(x, y - err, y + err, alpha=0.2)

# 12 somites 12 legs
y, err = mean_std("results/long/12s12l/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, '-.', label='s:12, l:12')
plt.fill_between(x, y - err, y + err, alpha=0.2)

# 12 somties 7 legs
y, err = mean_std("results/long/12s7l/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, 'o', label='s:12, l:7', markersize=2)
plt.fill_between(x, y - err, y + err, alpha=0.2)

# 32 somites 32 legs
y, err = mean_std("results/long/32s32l/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, 'v', label='s:32, l:32', markersize=2)
plt.fill_between(x, y - err, y + err, alpha=0.2)

# 32 somites 20 legs
# y, err = mean_std("results/long/32s20l/run0", "distance", "distance")
# x = np.arange(len(y))
# plt.plot(x, y, label='s:32, l:20')
# plt.fill_between(x, y - err, y + err, alpha=0.2)


plt.legend(loc='upper right')


plt.xlabel("Episodes")
plt.ylabel("Locomotion distance per 5000 steps")

plt.savefig("graphs/LearningCurve_SeveralSomiteNumber.png")
plt.savefig("graphs/LearningCurve_SeveralSomiteNumber.pdf")

# %%
# PEPG
y, err = mean_std("results/opt_comp/pepg/run1", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, '-', label='PEPG', markersize=2)
plt.fill_between(x, y - err, y + err, alpha=0.2)

# DDPG
y, err = mean_std("results/opt_comp/ddpg/run0", "distance", "distance")
x = np.arange(len(y))
plt.plot(x, y, ':', label='DDPG', markersize=2)
plt.fill_between(x, y - err, y + err, alpha=0.2)

plt.legend(loc='lower right')

plt.ylim([-0.05, 0.18])


plt.xlabel("Episodes")
plt.ylabel("Locomotion distance")

plt.savefig("graphs/LearningCurve_TrainingMethodsCmp.pdf")
plt.savefig("graphs/LearningCurve_TrainingMethodsCmp.png")
